# %%
from normalizer import get_normalizer_stats

# %reload_ext autoreload
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
a = get_normalizer_stats()

# %%
a
# Out:
# {'shift_20_days_sealevel_max_05001': {'mean': 273.21523647691873,
#   'std': 154.82919298495455},
#  'demodule_365_sealevel_max_05001': {'mean': 282.0134279753842,
#   'std': 98.6077220788778},
#  'past_year_sealevel_max_3D_05001': {'mean': 272.7204600522363,
#   'std': 152.7338324802126},
#  'past_year_sealevel_max_05001': {'mean': 272.77239686585483,
#   'std': 153.45888678700902},
#  'shift_30_days_sealevel_max_05001': {'mean': 273.1241385820825,
#   'std': 154.8083783082094},
#  'demodule_121_sealevel_max_05001': {'mean': 0.31900365507423006,
#   'std': 59.1210860243134},
#  'shift_10_days_sealevel_max_05001': {'mean': 273.32106107807044,
#   'std': 154.85957012667095},
#  'shift_20_days_sealevel_max_05002': {'mean': 434.3317757009346,
#   'std': 172.62603411711578},
#  'demodule_365_sealevel_max_05002': {'mean': 442.67085488327604,
#   'std': 126.1013936063462},
#  'past_year_sealevel_max_3D_05002': {'mean': 433.65757261084207,
#   'std': 170.36392616453517},
# ...
